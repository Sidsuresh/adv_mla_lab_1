# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/raw/wfh.csv")
df.head()
# Out:
#    id  distance_from_office salary_range  gas_price_per_litre  \
# 0   0              5.962247    40K - 60K             2.119485
# 1   1              0.535872    40K - 60K             2.357199
# 2   2              1.969519    40K - 60K             2.366849
# 3   3              2.530410    20K - 40K             2.318722
# 4   4              2.253635         60K+             2.221265
#
#    public_transportation_cost  wfh_prev_workday   workday    tenure  \
# 0                    8.568058             False    Friday  0.212653
# 1                    5.425382              True   Tuesday  4.927549
# 2                    8.247158             False    Monday  0.520817
# 3                    7.944251             False   Tuesday  0.453649
# 4                    8.884478              True  Thursday  5.695263
#
#    work_home_actual
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 1

# %%
df.shape
# Out:
# (50000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          50000 non-null  int64
#  1   distance_from_office        50000 non-null  float64
#  2   salary_range                50000 non-null  object
#  3   gas_price_per_litre         50000 non-null  float64
#  4   public_transportation_cost  50000 non-null  float64
#  5   wfh_prev_workday            50000 non-null  bool
#  6   workday                     50000 non-null  object
#  7   tenure                      50000 non-null  float64
#  8   work_home_actual            50000 non-null  int64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#                  id  distance_from_office  gas_price_per_litre  \
# count  50000.000000          50000.000000         50000.000000
# mean   24999.500000              3.929033             2.049616
# std    14433.901067              4.079528             0.334385
# min        0.000000              0.002210             1.400369
# 25%    12499.750000              0.897909             1.769163
# 50%    24999.500000              2.380855             2.189073
# 75%    37499.250000              5.679015             2.337894
# max    49999.000000             19.912896             2.399916
#
#        public_transportation_cost        tenure  work_home_actual
# count                50000.000000  50000.000000      50000.000000
# mean                     7.323907      4.600040          0.499580
# std                      1.630390      2.301937          0.500005
# min                      4.003417      0.002253          0.000000
# 25%                      6.109763      2.797947          0.000000
# 50%                      8.074422      5.584845          0.000000
# 75%                      8.627489      6.531917          1.000000
# max                      8.998112      6.997167          1.000000

# %%
df_cleaned = df.copy()

# %%
y = df_cleaned.pop('work_home_actual')

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 49995    1
# 49996    0
# 49997    1
# 49998    0
# 49999    1
# Name: work_home_actual, Length: 50000, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_enc = OrdinalEncoder(categories = [['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']])

# %%
df_cleaned['workday'] = ord_enc.fit_transform(df_cleaned[['workday']])

# %%
df_cleaned = pd.get_dummies(df_cleaned, columns = ['salary_range'])

# %%
df_cleaned.drop(['id'], axis = 1, inplace = True)

# %%
df_cleaned.head()
# Out:
#    distance_from_office  gas_price_per_litre  public_transportation_cost  \
# 0              5.962247             2.119485                    8.568058
# 1              0.535872             2.357199                    5.425382
# 2              1.969519             2.366849                    8.247158
# 3              2.530410             2.318722                    7.944251
# 4              2.253635             2.221265                    8.884478
#
#    wfh_prev_workday  workday    tenure  salary_range_0 - 20K  \
# 0             False      4.0  0.212653                 False
# 1              True      1.0  4.927549                 False
# 2             False      0.0  0.520817                 False
# 3             False      1.0  0.453649                 False
# 4              True      3.0  5.695263                 False
#
#    salary_range_20K - 40K  salary_range_40K - 60K  salary_range_60K+
# 0                   False                    True              False
# 1                   False                    True              False
# 2                   False                    True              False
# 3                    True                   False              False
# 4                   False                   False               True

# %%
from sklearn.model_selection import train_test_split

# %%
X_data, X_test, y_data, y_test =  train_test_split(df_cleaned, y, test_size = 0.2, random_state = 42)
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size = 0.2, random_state = 42)

# %%
print(X_train.shape)
# Out:
# (32000, 10)

# %%
print(X_val.shape)
# Out:
# (8000, 10)

# %%
print(X_test.shape)
# Out:
# (10000, 10)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (32000,)
# (8000,)
# (10000,)

# %%
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_val.to_csv('../data/processed/X_val.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_val.to_csv('../data/processed/y_val.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

# %%
from sklearn.dummy import DummyClassifier

# %%
base_clf = DummyClassifier(strategy = "most_frequent")

# %%
base_clf.fit(X_train, y_train)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
from sklearn.metrics import roc_auc_score

# %%
y_proba_preds = base_clf.predict_proba(X_train)
roc_auc_score(y_train, y_proba_preds[:, 1])
# Out:
# np.float64(0.5)
